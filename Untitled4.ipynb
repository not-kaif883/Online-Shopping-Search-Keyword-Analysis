# %%
import pandas as pd

data = {
    "keyword": ["iphone 14", "laptop", "running shoes", "air fryer", "headphones"],
    "category": ["Electronics", "Electronics", "Fashion", "Home", "Electronics"],
    "search_count": [5200, 6000, 4800, 4200, 5000]
}

df = pd.DataFrame(data)
df.to_csv("search_keywords.csv", index=False)

# %%
df = pd.read_csv("search_keywords.csv")
print(df.head())
print(df.info())
# Out:
#          keyword     category  search_count
# 0      iphone 14  Electronics          5200
# 1         laptop  Electronics          6000
# 2  running shoes      Fashion          4800
# 3      air fryer         Home          4200
# 4     headphones  Electronics          5000
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   keyword       5 non-null      object
#  1   category      5 non-null      object
#  2   search_count  5 non-null      int64
# dtypes: int64(1), object(2)
# memory usage: 252.0+ bytes
# None

# %%
df = pd.read_csv("search_keywords.csv", encoding="latin1")
